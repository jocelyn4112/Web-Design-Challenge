# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from scipy import stats

# Import API key
from config import api
# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 618

# %%
# Perform API Calls
# Perform a weather check on each city using a series of successive API calls.
#* Include a print log of each city as it'sbeing processed (with the city number and city name).
url = "http://api.openweathermap.org/data/2.5/weather"
query = "Nashville"
url_params = {
    "api" : api,
    "q" : query,
    'page': 2
}
city_name = []
Lat = []
Long = []
MaxTemp = []
Humidity = []
Cloundiness = []
WindSpeed = []
Date = []
#enum
for city in cities:
   
    try: 
        # Build partial query URL
        query_url = f"{url}?units=Imperial&appid={api}&q={city}"
        #query_url
    

    
        print("City : ",city)
        city_weather = requests.get(query_url).json()
    
    
    
        print(city_weather)
        city_name.append(city_weather['name'])
        Lat.append(city_weather['coord']['lat'])
        Long.append(city_weather['coord']['lon'])
        MaxTemp.append(city_weather['main']['temp_max'])
        Humidity.append(city_weather['main']['humidity'])
        Cloundiness.append(city_weather['clouds']['all'])
        WindSpeed.append(city_weather['wind']['speed'])
      
    except: 
        print("City not found")
    
    time.sleep(1)
print(city_name)
# Out:
# City :  upernavik
# {'coord': {'lon': -56.15, 'lat': 72.79}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 11.98, 'feels_like': 0.91, 'temp_min': 11.98, 'temp_max': 11.98, 'pressure': 1001, 'humidity': 82, 'sea_level': 1001, 'grnd_level': 1001}, 'visibility': 10000, 'wind': {'speed': 9.13, 'deg': 26}, 'clouds': {'all': 0}, 'dt': 1603913722, 'sys': {'country': 'GL', 'sunrise': 1603888230, 'sunset': 1603909559}, 'timezone': -10800, 'id': 3418910, 'name': 'Upernavik', 'cod': 200}
# City :  illoqqortoormiut
# {'cod': '404', 'message': 'city not found'}
# City not found
# City :  iqaluit
# {'coord': {'lon': -68.51, 'lat': 63.75}, 'weather': [{'id': 521, 'main': 'Rain', 'description': 'shower rain', 'icon': '09d'}], 'base': 'stations', 'main': {'temp': 17.29, 'feels_like': 6.12, 'temp_min': 17.01, 'temp_max': 17.6, 'pressure': 1003, 'humidity': 61}, 'visibility': 10000, 'wind': {'speed': 9.17, 'deg': 60}, 'clouds': {'all': 90}, 'dt': 1603913724, 'sys': {'type': 1, 'id': 797, 'country': 'CA', 'sunrise': 1603886631, 'sunset': 1603917091}, 'timezone': -14400, 'id': 5983720, 'name': 'Iqaluit', 'cod': 200}
# City :  talnakh
# {'coord': {'lon': 88.4, 'lat': 69.49}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': -1.97, 'feels_like': -11.29, 'temp_min': -1.97, 'temp_max': -1.97, 'pressure': 1025, 'humidity': 76, 'sea_level': 1025, 'grnd_level': 1013}, 'visibility': 10000, 'wind': {'speed': 4.88, 'deg': 121}, 'clouds': {'all': 0}, 'dt': 1603913725, 'sys': {'country': 'RU', 'sunrise': 1603937852, 'sunset': 1603963349}, 'timezone': 25200, 'id': 1490256, 'name': 'Talnakh', 'cod': 200}
# City :  ilinsko-podomskoye
# {'cod': '404', 'message': 'city not found'}
# City not found
# City :  sterlibashevo
# {'coord': {'lon': 55.26, 'lat': 53.44}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 31.08, 'feels_like': 23.59, 'temp_min': 31.08, 'temp_max': 31.08, 'pressure': 1036, 'humidity': 92, 'sea_level': 1036, 'grnd_level': 1003}, 'visibility': 10000, 'wind': {'speed': 6.22, 'deg': 227}, 'clouds': {'all': 6}, 'dt': 1603913727, 'sys': {'country': 'RU', 'sunrise': 1603941143, 'sunset': 1603975965}, 'timezone': 18000, 'id': 487498, 'name': 'Sterlibashevo', 'cod': 200}
# City :  albany
# {'coord': {'lon': -73.97, 'lat': 42.6}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 49.62, 'feels_like': 47.71, 'temp_min': 48.99, 'temp_max': 50, 'pressure': 1011, 'humidity': 88}, 'visibility': 10000, 'wind': {'speed': 1.83, 'deg': 242}, 'clouds': {'all': 96}, 'dt': 1603913728, 'sys': {'type': 3, 'id': 19530, 'country': 'US', 'sunrise': 1603884309, 'sunset': 1603922034}, 'timezone': -14400, 'id': 5106841, 'name': 'Albany', 'cod': 200}
# City :  kapaa
# {'coord': {'lon': -159.32, 'lat': 22.08}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 75.31, 'feels_like': 80.15, 'temp_min': 73.99, 'temp_max': 77, 'pressure': 1014, 'humidity': 83}, 'visibility': 10000, 'wind': {'speed': 4.74, 'deg': 346}, 'clouds': {'all': 40}, 'dt': 1603913729, 'sys': {'type': 1, 'id': 7873, 'country': 'US', 'sunrise': 1603903165, 'sunset': 1603944144}, 'timezone': -36000, 'id': 5848280, 'name': 'Kapaa', 'cod': 200}
# City :  dikson
# {'coord': {'lon': 80.55, 'lat': 73.51}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 2.71, 'feels_like': -16.13, 'temp_min': 2.71, 'temp_max': 2.71, 'pressure': 1021, 'humidity': 92, 'sea_level': 1021, 'grnd_level': 1015}, 'visibility': 10000, 'wind': {'speed': 22.35, 'deg': 174}, 'clouds': {'all': 2}, 'dt': 1603913724, 'sys': {'country': 'RU', 'sunrise': 1603942759, 'sunset': 1603962211}, 'timezone': 25200, 'id': 1507390, 'name': 'Dikson', 'cod': 200}
# City :  ushuaia
# {'coord': {'lon': -68.3, 'lat': -54.8}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 46.4, 'feels_like': 32.13, 'temp_min': 46.4, 'temp_max': 46.4, 'pressure': 995, 'humidity': 61}, 'visibility': 10000, 'wind': {'speed': 19.46, 'deg': 230, 'gust': 35.57}, 'clouds': {'all': 75}, 'dt': 1603913540, 'sys': {'type': 1, 'id': 8303, 'country': 'AR', 'sunrise': 1603875121, 'sunset': 1603928501}, 'timezone': -10800, 'id': 3833367, 'name': 'Ushuaia', 'cod': 200}
# City :  saskylakh
# {'coord': {'lon': 114.08, 'lat': 71.92}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 5.5, 'feels_like': -8.27, 'temp_min': 5.5, 'temp_max': 5.5, 'pressure': 1029, 'humidity': 92, 'sea_level': 1029, 'grnd_level': 1028}, 'visibility': 1320, 'wind': {'speed': 13.56, 'deg': 292}, 'clouds': {'all': 100}, 'dt': 1603913733, 'sys': {'country': 'RU', 'sunrise': 1603933254, 'sunset': 1603955622}, 'timezone': 32400, 'id': 2017155, 'name': 'Saskylakh', 'cod': 200}
# City :  lipin bor
# {'coord': {'lon': 37.98, 'lat': 60.26}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 43.39, 'feels_like': 36.72, 'temp_min': 43.39, 'temp_max': 43.39, 'pressure': 1018, 'humidity': 94, 'sea_level': 1018, 'grnd_level': 1002}, 'visibility': 10000, 'wind': {'speed': 8.55, 'deg': 209}, 'clouds': {'all': 82}, 'dt': 1603913735, 'sys': {'country': 'RU', 'sunrise': 1603860088, 'sunset': 1603892521}, 'timezone': 10800, 'id': 535113, 'name': 'Lipin Bor', 'cod': 200}
# City :  portland
# {'coord': {'lon': -122.68, 'lat': 45.52}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 55.08, 'feels_like': 53.46, 'temp_min': 53.01, 'temp_max': 59, 'pressure': 1024, 'humidity': 70}, 'visibility': 10000, 'wind': {'speed': 1.01, 'deg': 355, 'gust': 5.01}, 'clouds': {'all': 0}, 'dt': 1603913547, 'sys': {'type': 3, 'id': 2008548, 'country': 'US', 'sunrise': 1603896325, 'sunset': 1603933397}, 'timezone': -25200, 'id': 5746545, 'name': 'Portland', 'cod': 200}
# City :  sena madureira
# {'coord': {'lon': -68.66, 'lat': -9.07}, 'weather': [{'id': 503, 'main': 'Rain', 'description': 'very heavy rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 95.05, 'feels_like': 100.76, 'temp_min': 95.05, 'temp_max': 95.05, 'pressure': 1000, 'humidity': 44, 'sea_level': 1000, 'grnd_level': 986}, 'visibility': 10000, 'wind': {'speed': 3.11, 'deg': 322}, 'rain': {'1h': 17.756}, 'clouds': {'all': 87}, 'dt': 1603913737, 'sys': {'country': 'BR', 'sunrise': 1603879569, 'sunset': 1603924225}, 'timezone': -18000, 'id': 3662155, 'name': 'Sena Madureira', 'cod': 200}
# City :  atuona
# {'coord': {'lon': -139.03, 'lat': -9.8}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 78.3, 'feels_like': 75.96, 'temp_min': 78.3, 'temp_max': 78.3, 'pressure': 1015, 'humidity': 67, 'sea_level': 1015, 'grnd_level': 1012}, 'visibility': 10000, 'wind': {'speed': 14.65, 'deg': 100}, 'clouds': {'all': 21}, 'dt': 1603913724, 'sys': {'country': 'PF', 'sunrise': 1603896411, 'sunset': 1603941159}, 'timezone': -34200, 'id': 4020109, 'name': 'Atuona', 'cod': 200}
# City :  taolanaro
# {'cod': '404', 'message': 'city not found'}
# City not found
# City :  mataura
# {'coord': {'lon': 168.86, 'lat': -46.19}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 48.99, 'feels_like': 46.13, 'temp_min': 48.99, 'temp_max': 48.99, 'pressure': 1026, 'humidity': 86}, 'visibility': 10000, 'wind': {'speed': 3, 'deg': 98, 'gust': 8.01}, 'clouds': {'all': 100}, 'dt': 1603913741, 'sys': {'type': 3, 'id': 2008959, 'country': 'NZ', 'sunrise': 1603905921, 'sunset': 1603956661}, 'timezone': 46800, 'id': 6201424, 'name': 'Mataura', 'cod': 200}
# City :  broken hill
# {'coord': {'lon': 141.43, 'lat': -31.95}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 55.4, 'feels_like': 49.28, 'temp_min': 55.4, 'temp_max': 55.4, 'pressure': 1013, 'humidity': 66}, 'visibility': 10000, 'wind': {'speed': 8.48, 'deg': 5}, 'clouds': {'all': 75}, 'dt': 1603913742, 'sys': {'type': 1, 'id': 9491, 'country': 'AU', 'sunrise': 1603913968, 'sunset': 1603961780}, 'timezone': 37800, 'id': 2173911, 'name': 'Broken Hill', 'cod': 200}
# City :  jamestown
# {'coord': {'lon': -79.24, 'lat': 42.1}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 49.01, 'feels_like': 41.49, 'temp_min': 46.4, 'temp_max': 50, 'pressure': 1015, 'humidity': 87}, 'visibility': 10000, 'wind': {'speed': 11.41, 'deg': 240}, 'clouds': {'all': 90}, 'dt': 1603913669, 'sys': {'type': 1, 'id': 4588, 'country': 'US', 'sunrise': 1603885524, 'sunset': 1603923348}, 'timezone': -14400, 'id': 5122534, 'name': 'Jamestown', 'cod': 200}
# City :  mwanza
# {'coord': {'lon': 32.9, 'lat': -2.52}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 71.6, 'feels_like': 73.49, 'temp_min': 71.6, 'temp_max': 71.6, 'pressure': 1015, 'humidity': 83}, 'visibility': 10000, 'wind': {'speed': 6.93, 'deg': 120}, 'clouds': {'all': 75}, 'dt': 1603913745, 'sys': {'type': 1, 'id': 2631, 'country': 'TZ', 'sunrise': 1603855576, 'sunset': 1603899471}, 'timezone': 10800, 'id': 152224, 'name': 'Mwanza', 'cod': 200}
# City :  hithadhoo
# {'coord': {'lon': 73.08, 'lat': -0.6}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 83.23, 'feels_like': 86.74, 'temp_min': 83.23, 'temp_max': 83.23, 'pressure': 1010, 'humidity': 74, 'sea_level': 1010, 'grnd_level': 1010}, 'visibility': 10000, 'wind': {'speed': 11.18, 'deg': 272}, 'clouds': {'all': 6}, 'dt': 1603913746, 'sys': {'country': 'MV', 'sunrise': 1603932438, 'sunset': 1603976117}, 'timezone': 18000, 'id': 1282256, 'name': 'Hithadhoo', 'cod': 200}
# City :  arraial do cabo
# {'coord': {'lon': -42.03, 'lat': -22.97}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 85.5, 'feels_like': 88.14, 'temp_min': 82.4, 'temp_max': 89.6, 'pressure': 1004, 'humidity': 74}, 'visibility': 10000, 'wind': {'speed': 14.99, 'deg': 100}, 'clouds': {'all': 20}, 'dt': 1603913747, 'sys': {'type': 1, 'id': 8326, 'country': 'BR', 'sunrise': 1603872302, 'sunset': 1603918711}, 'timezone': -10800, 'id': 3471451, 'name': 'Arraial do Cabo', 'cod': 200}
# City :  changji
# {'coord': {'lon': 87.32, 'lat': 44.02}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 41, 'feels_like': 34.18, 'temp_min': 41, 'temp_max': 41, 'pressure': 1026, 'humidity': 56}, 'visibility': 10000, 'wind': {'speed': 4.47, 'deg': 240}, 'clouds': {'all': 0}, 'dt': 1603913748, 'sys': {'type': 1, 'id': 9677, 'country': 'CN', 'sunrise': 1603932192, 'sunset': 1603969528}, 'timezone': 28800, 'id': 1529569, 'name': 'Changji', 'cod': 200}
# City :  tuatapere
# {'coord': {'lon': 167.68, 'lat': -46.13}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 48.99, 'feels_like': 46.13, 'temp_min': 48.99, 'temp_max': 48.99, 'pressure': 1026, 'humidity': 86}, 'visibility': 10000, 'wind': {'speed': 3, 'deg': 98, 'gust': 8.01}, 'rain': {'1h': 0.24}, 'clouds': {'all': 100}, 'dt': 1603913749, 'sys': {'type': 3, 'id': 2008959, 'country': 'NZ', 'sunrise': 1603906212, 'sunset': 1603956936}, 'timezone': 46800, 'id': 2180815, 'name': 'Tuatapere', 'cod': 200}
# City :  hilo
# {'coord': {'lon': -155.09, 'lat': 19.73}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 79.74, 'feels_like': 81.34, 'temp_min': 78.01, 'temp_max': 81, 'pressure': 1013, 'humidity': 65}, 'visibility': 10000, 'wind': {'speed': 8.05, 'deg': 190}, 'clouds': {'all': 1}, 'dt': 1603913750, 'sys': {'type': 1, 'id': 7881, 'country': 'US', 'sunrise': 1603901998, 'sunset': 1603943280}, 'timezone': -36000, 'id': 5855927, 'name': 'Hilo', 'cod': 200}
# City :  hermanus
# {'coord': {'lon': 19.23, 'lat': -34.42}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 63, 'feels_like': 56.93, 'temp_min': 63, 'temp_max': 63, 'pressure': 1012, 'humidity': 65}, 'visibility': 10000, 'wind': {'speed': 11.43, 'deg': 331}, 'clouds': {'all': 63}, 'dt': 1603913751, 'sys': {'type': 3, 'id': 2006131, 'country': 'ZA', 'sunrise': 1603856724, 'sunset': 1603904885}, 'timezone': 7200, 'id': 3366880, 'name': 'Hermanus', 'cod': 200}
# City :  palabuhanratu
# {'cod': '404', 'message': 'city not found'}
# City not found
# City :  lagoa
# {'coord': {'lon': -27.98, 'lat': 39.05}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 64.71, 'feels_like': 60.58, 'temp_min': 64.71, 'temp_max': 64.71, 'pressure': 1019, 'humidity': 72, 'sea_level': 1019, 'grnd_level': 1014}, 'visibility': 10000, 'wind': {'speed': 10.33, 'deg': 190}, 'clouds': {'all': 1}, 'dt': 1603913754, 'sys': {'country': 'PT', 'sunrise': 1603872918, 'sunset': 1603911350}, 'timezone': -3600, 'id': 3372964, 'name': 'Lagoa', 'cod': 200}
# City :  guerrero negro
# {'coord': {'lon': -114.06, 'lat': 27.98}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 74.71, 'feels_like': 67.3, 'temp_min': 74.71, 'temp_max': 74.71, 'pressure': 1015, 'humidity': 19, 'sea_level': 1015, 'grnd_level': 1015}, 'visibility': 10000, 'wind': {'speed': 6.24, 'deg': 277}, 'clouds': {'all': 0}, 'dt': 1603913482, 'sys': {'country': 'MX', 'sunrise': 1603892701, 'sunset': 1603932885}, 'timezone': -25200, 'id': 4021858, 'name': 'Guerrero Negro', 'cod': 200}
# City :  belushya guba
# {'cod': '404', 'message': 'city not found'}
# City not found
# City :  busselton
# {'coord': {'lon': 115.33, 'lat': -33.65}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 53.33, 'feels_like': 44.29, 'temp_min': 48.99, 'temp_max': 55.99, 'pressure': 1013, 'humidity': 50}, 'visibility': 10000, 'wind': {'speed': 10.56, 'deg': 108}, 'clouds': {'all': 0}, 'dt': 1603913757, 'sys': {'type': 3, 'id': 2011706, 'country': 'AU', 'sunrise': 1603920082, 'sunset': 1603968193}, 'timezone': 28800, 'id': 2075265, 'name': 'Busselton', 'cod': 200}
# City :  one hundred mile house
# {'cod': '404', 'message': 'city not found'}
# City not found
# City :  bredasdorp
# {'coord': {'lon': 20.04, 'lat': -34.53}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 64.4, 'feels_like': 61.61, 'temp_min': 64.4, 'temp_max': 64.4, 'pressure': 1011, 'humidity': 68}, 'visibility': 10000, 'wind': {'speed': 6.93, 'deg': 80}, 'clouds': {'all': 100}, 'dt': 1603913759, 'sys': {'type': 1, 'id': 1966, 'country': 'ZA', 'sunrise': 1603856520, 'sunset': 1603904700}, 'timezone': 7200, 'id': 1015776, 'name': 'Bredasdorp', 'cod': 200}
# City :  new norfolk
# {'coord': {'lon': 147.06, 'lat': -42.78}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 47.48, 'feels_like': 44.13, 'temp_min': 46, 'temp_max': 48.99, 'pressure': 1015, 'humidity': 73}, 'visibility': 10000, 'wind': {'speed': 1.74, 'deg': 314}, 'clouds': {'all': 4}, 'dt': 1603913761, 'sys': {'type': 3, 'id': 2031307, 'country': 'AU', 'sunrise': 1603911564, 'sunset': 1603961482}, 'timezone': 39600, 'id': 2155415, 'name': 'New Norfolk', 'cod': 200}
# City :  vlakhokerasea
# {'cod': '404', 'message': 'city not found'}
# City not found
# City :  georgetown
# {'coord': {'lon': 100.34, 'lat': 5.41}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 79.41, 'feels_like': 88.2, 'temp_min': 78.01, 'temp_max': 80.6, 'pressure': 1009, 'humidity': 88}, 'visibility': 8000, 'wind': {'speed': 3.36, 'deg': 80}, 'rain': {'1h': 0.87}, 'clouds': {'all': 20}, 'dt': 1603913623, 'sys': {'type': 1, 'id': 9429, 'country': 'MY', 'sunrise': 1603926242, 'sunset': 1603969228}, 'timezone': 28800, 'id': 1735106, 'name': 'George Town', 'cod': 200}
# City :  vaini
# {'coord': {'lon': -175.2, 'lat': -21.2}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 73.4, 'feels_like': 72.55, 'temp_min': 73.4, 'temp_max': 73.4, 'pressure': 1016, 'humidity': 73}, 'visibility': 10000, 'wind': {'speed': 10.29, 'deg': 110}, 'clouds': {'all': 20}, 'dt': 1603913764, 'sys': {'type': 1, 'id': 7285, 'country': 'TO', 'sunrise': 1603990733, 'sunset': 1604036992}, 'timezone': 46800, 'id': 4032243, 'name': 'Vaini', 'cod': 200}
# City :  kamenskoye
# {'cod': '404', 'message': 'city not found'}
# City not found
# City :  tsihombe
# {'cod': '404', 'message': 'city not found'}
# City not found
# City :  tuktoyaktuk
# {'coord': {'lon': -133.04, 'lat': 69.45}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13d'}], 'base': 'stations', 'main': {'temp': 21.2, 'feels_like': 1.9, 'temp_min': 21.2, 'temp_max': 21.2, 'pressure': 1009, 'humidity': 92}, 'visibility': 4828, 'wind': {'speed': 25.28, 'deg': 280, 'gust': 34.45}, 'clouds': {'all': 90}, 'dt': 1603913767, 'sys': {'type': 1, 'id': 942, 'country': 'CA', 'sunrise': 1603904470, 'sunset': 1603930225}, 'timezone': -21600, 'id': 6170031, 'name': 'Tuktoyaktuk', 'cod': 200}
# City :  srednekolymsk
# {'coord': {'lon': 153.68, 'lat': 67.45}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 6.73, 'feels_like': -0.44, 'temp_min': 6.73, 'temp_max': 6.73, 'pressure': 1029, 'humidity': 94, 'sea_level': 1029, 'grnd_level': 1027}, 'visibility': 10000, 'wind': {'speed': 1.97, 'deg': 195}, 'clouds': {'all': 92}, 'dt': 1603913769, 'sys': {'country': 'RU', 'sunrise': 1603921137, 'sunset': 1603948731}, 'timezone': 39600, 'id': 2121025, 'name': 'Srednekolymsk', 'cod': 200}
# City :  cape town
# {'coord': {'lon': 18.42, 'lat': -33.93}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 60.76, 'feels_like': 51.42, 'temp_min': 59, 'temp_max': 62.01, 'pressure': 1014, 'humidity': 82}, 'visibility': 10000, 'wind': {'speed': 19.46, 'deg': 330}, 'clouds': {'all': 75}, 'dt': 1603913471, 'sys': {'type': 1, 'id': 1899, 'country': 'ZA', 'sunrise': 1603856961, 'sunset': 1603905037}, 'timezone': 7200, 'id': 3369157, 'name': 'Cape Town', 'cod': 200}
# City :  marsh harbour
# {'coord': {'lon': -77.06, 'lat': 26.54}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 81.55, 'feels_like': 83.23, 'temp_min': 81.55, 'temp_max': 81.55, 'pressure': 1015, 'humidity': 79, 'sea_level': 1015, 'grnd_level': 1014}, 'visibility': 10000, 'wind': {'speed': 14.79, 'deg': 97}, 'clouds': {'all': 29}, 'dt': 1603913715, 'sys': {'country': 'BS', 'sunrise': 1603883715, 'sunset': 1603924111}, 'timezone': -14400, 'id': 3571913, 'name': 'Marsh Harbour', 'cod': 200}
# City :  castro
# {'coord': {'lon': -50.01, 'lat': -24.79}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 79.66, 'feels_like': 78.64, 'temp_min': 79.66, 'temp_max': 79.66, 'pressure': 1004, 'humidity': 42, 'sea_level': 1004, 'grnd_level': 897}, 'visibility': 10000, 'wind': {'speed': 4.32, 'deg': 284}, 'clouds': {'all': 0}, 'dt': 1603913767, 'sys': {'country': 'BR', 'sunrise': 1603874088, 'sunset': 1603920754}, 'timezone': -10800, 'id': 3466704, 'name': 'Castro', 'cod': 200}
# City :  yellowknife
# {'coord': {'lon': -114.35, 'lat': 62.46}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13d'}], 'base': 'stations', 'main': {'temp': 23.77, 'feels_like': 13.93, 'temp_min': 21.99, 'temp_max': 24.8, 'pressure': 1014, 'humidity': 73}, 'visibility': 10000, 'wind': {'speed': 8.05, 'deg': 240}, 'clouds': {'all': 90}, 'dt': 1603913626, 'sys': {'type': 1, 'id': 1007, 'country': 'CA', 'sunrise': 1603897279, 'sunset': 1603928445}, 'timezone': -21600, 'id': 6185377, 'name': 'Yellowknife', 'cod': 200}
# City :  quang ngai
# {'coord': {'lon': 108.8, 'lat': 15.12}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 73.44, 'feels_like': 74.84, 'temp_min': 73.44, 'temp_max': 73.44, 'pressure': 1005, 'humidity': 86, 'sea_level': 1005, 'grnd_level': 1003}, 'visibility': 10000, 'wind': {'speed': 10.16, 'deg': 161}, 'clouds': {'all': 61}, 'dt': 1603913774, 'sys': {'country': 'VN', 'sunrise': 1603924785, 'sunset': 1603966625}, 'timezone': 25200, 'id': 1568770, 'name': 'Quang Ngai', 'cod': 200}
# City :  temaraia
# {'cod': '404', 'message': 'city not found'}
# City not found
# City :  sao filipe
# {'coord': {'lon': -24.5, 'lat': 14.9}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 81.84, 'feels_like': 88.75, 'temp_min': 81.84, 'temp_max': 81.84, 'pressure': 1012, 'humidity': 68, 'sea_level': 1012, 'grnd_level': 1006}, 'visibility': 10000, 'wind': {'speed': 1.48, 'deg': 100}, 'clouds': {'all': 69}, 'dt': 1603913776, 'sys': {'country': 'CV', 'sunrise': 1603870352, 'sunset': 1603912246}, 'timezone': -3600, 'id': 3374210, 'name': 'São Filipe', 'cod': 200}
# City :  poum
# {'coord': {'lon': 164.02, 'lat': -20.23}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 76.39, 'feels_like': 71.44, 'temp_min': 76.39, 'temp_max': 76.39, 'pressure': 1014, 'humidity': 77, 'sea_level': 1014, 'grnd_level': 1014}, 'visibility': 10000, 'wind': {'speed': 21.14, 'deg': 88}, 'clouds': {'all': 0}, 'dt': 1603913777, 'sys': {'country': 'NC', 'sunrise': 1603909420, 'sunset': 1603955485}, 'timezone': 39600, 'id': 2138555, 'name': 'Poum', 'cod': 200}
# City :  tiksi
# {'coord': {'lon': 128.87, 'lat': 71.69}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 0.7, 'feels_like': -15.97, 'temp_min': 0.7, 'temp_max': 0.7, 'pressure': 1027, 'humidity': 91, 'sea_level': 1027, 'grnd_level': 1022}, 'visibility': 3101, 'wind': {'speed': 18.32, 'deg': 253}, 'clouds': {'all': 99}, 'dt': 1603913779, 'sys': {'country': 'RU', 'sunrise': 1603929515, 'sunset': 1603952261}, 'timezone': 32400, 'id': 2015306, 'name': 'Tiksi', 'cod': 200}
# City :  wajid
# {'coord': {'lon': 43.25, 'lat': 3.81}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 77.58, 'feels_like': 76.98, 'temp_min': 77.58, 'temp_max': 77.58, 'pressure': 1012, 'humidity': 74, 'sea_level': 1012, 'grnd_level': 969}, 'visibility': 10000, 'wind': {'speed': 13.4, 'deg': 150}, 'rain': {'1h': 0.22}, 'clouds': {'all': 50}, 'dt': 1603913780, 'sys': {'country': 'SO', 'sunrise': 1603853450, 'sunset': 1603896630}, 'timezone': 10800, 'id': 50814, 'name': 'Wajid', 'cod': 200}
# City :  jaru
# {'coord': {'lon': -62.47, 'lat': -10.44}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 93.54, 'feels_like': 98.42, 'temp_min': 93.54, 'temp_max': 93.54, 'pressure': 1001, 'humidity': 45, 'sea_level': 1001, 'grnd_level': 984}, 'visibility': 10000, 'wind': {'speed': 3.96, 'deg': 347}, 'clouds': {'all': 100}, 'dt': 1603913781, 'sys': {'country': 'BR', 'sunrise': 1603878003, 'sunset': 1603922820}, 'timezone': -14400, 'id': 3925040, 'name': 'Jaru', 'cod': 200}
# City :  kaitangata
# {'coord': {'lon': 169.85, 'lat': -46.28}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 51.01, 'feels_like': 44.04, 'temp_min': 51.01, 'temp_max': 51.01, 'pressure': 1023, 'humidity': 85}, 'visibility': 10000, 'wind': {'speed': 11.01, 'deg': 270, 'gust': 15.01}, 'clouds': {'all': 100}, 'dt': 1603913783, 'sys': {'type': 3, 'id': 2000217, 'country': 'NZ', 'sunrise': 1603905672, 'sunset': 1603956435}, 'timezone': 46800, 'id': 2208248, 'name': 'Kaitangata', 'cod': 200}
# City :  aklavik
# {'coord': {'lon': -135.01, 'lat': 68.22}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 12.2, 'feels_like': 5.4, 'temp_min': 12.2, 'temp_max': 12.2, 'pressure': 1014, 'humidity': 85}, 'visibility': 10000, 'wind': {'speed': 1.66, 'deg': 30}, 'clouds': {'all': 75}, 'dt': 1603913638, 'sys': {'type': 1, 'id': 821, 'country': 'CA', 'sunrise': 1603904324, 'sunset': 1603931317}, 'timezone': -21600, 'id': 5882953, 'name': 'Aklavik', 'cod': 200}
# City :  nikolskoye
# {'coord': {'lon': 30.79, 'lat': 59.7}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 45.23, 'feels_like': 39.54, 'temp_min': 44.01, 'temp_max': 46.99, 'pressure': 1013, 'humidity': 87}, 'visibility': 10000, 'wind': {'speed': 6.71, 'deg': 170}, 'clouds': {'all': 0}, 'dt': 1603913785, 'sys': {'type': 1, 'id': 8926, 'country': 'RU', 'sunrise': 1603861688, 'sunset': 1603894372}, 'timezone': 10800, 'id': 546105, 'name': 'Nikolskoye', 'cod': 200}
# City :  novoagansk
# {'coord': {'lon': 76.66, 'lat': 61.94}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 4.8, 'feels_like': -6.54, 'temp_min': 4.8, 'temp_max': 4.8, 'pressure': 1019, 'humidity': 92, 'sea_level': 1019, 'grnd_level': 1011}, 'visibility': 10000, 'wind': {'speed': 9.17, 'deg': 328}, 'clouds': {'all': 0}, 'dt': 1603913786, 'sys': {'country': 'RU', 'sunrise': 1603937774, 'sunset': 1603969062}, 'timezone': 18000, 'id': 1497210, 'name': 'Novoagansk', 'cod': 200}
# City :  ifanadiana
# {'coord': {'lon': 47.63, 'lat': -21.3}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 65.16, 'feels_like': 69.26, 'temp_min': 65.16, 'temp_max': 65.16, 'pressure': 1021, 'humidity': 94, 'sea_level': 1021, 'grnd_level': 970}, 'visibility': 10000, 'wind': {'speed': 0.87, 'deg': 183}, 'rain': {'1h': 0.21}, 'clouds': {'all': 46}, 'dt': 1603913787, 'sys': {'country': 'MG', 'sunrise': 1603850906, 'sunset': 1603897071}, 'timezone': 10800, 'id': 1064366, 'name': 'Ifanadiana', 'cod': 200}
# City :  changying
# {'coord': {'lon': 123.32, 'lat': 52.87}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 14.31, 'feels_like': 6.75, 'temp_min': 14.31, 'temp_max': 14.31, 'pressure': 1028, 'humidity': 94, 'sea_level': 1028, 'grnd_level': 956}, 'visibility': 10000, 'wind': {'speed': 3.51, 'deg': 233}, 'clouds': {'all': 40}, 'dt': 1603913788, 'sys': {'country': 'CN', 'sunrise': 1603924696, 'sunset': 1603959744}, 'timezone': 28800, 'id': 6958004, 'name': 'Changying', 'cod': 200}
# City :  avarua
# {'coord': {'lon': -159.78, 'lat': -21.21}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 73.4, 'feels_like': 74.21, 'temp_min': 73.4, 'temp_max': 73.4, 'pressure': 1012, 'humidity': 83}, 'visibility': 8000, 'wind': {'speed': 10.29, 'deg': 90}, 'clouds': {'all': 36}, 'dt': 1603913790, 'sys': {'type': 1, 'id': 7271, 'country': 'CK', 'sunrise': 1603900669, 'sunset': 1603946860}, 'timezone': -36000, 'id': 4035715, 'name': 'Avarua', 'cod': 200}
# City :  saint-francois
# {'coord': {'lon': 3.91, 'lat': 46.42}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 56.64, 'feels_like': 53.02, 'temp_min': 55.99, 'temp_max': 57.2, 'pressure': 1019, 'humidity': 67}, 'visibility': 10000, 'wind': {'speed': 4.7, 'deg': 230}, 'clouds': {'all': 90}, 'dt': 1603913791, 'sys': {'type': 1, 'id': 6499, 'country': 'FR', 'sunrise': 1603866018, 'sunset': 1603902944}, 'timezone': 3600, 'id': 2980080, 'name': 'Saint-François', 'cod': 200}
# City :  cherskiy
# {'coord': {'lon': 161.3, 'lat': 68.75}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 4.53, 'feels_like': -5.26, 'temp_min': 4.53, 'temp_max': 4.53, 'pressure': 1029, 'humidity': 94, 'sea_level': 1029, 'grnd_level': 1029}, 'visibility': 2820, 'wind': {'speed': 6.44, 'deg': 197}, 'clouds': {'all': 100}, 'dt': 1603913792, 'sys': {'country': 'RU', 'sunrise': 1603919912, 'sunset': 1603946299}, 'timezone': 39600, 'id': 2126199, 'name': 'Cherskiy', 'cod': 200}
# City :  huancavelica
# {'coord': {'lon': -74.98, 'lat': -12.77}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 59.22, 'feels_like': 52.39, 'temp_min': 59.22, 'temp_max': 59.22, 'pressure': 1008, 'humidity': 29, 'sea_level': 1008, 'grnd_level': 627}, 'visibility': 10000, 'wind': {'speed': 4.59, 'deg': 126}, 'clouds': {'all': 94}, 'dt': 1603913793, 'sys': {'country': 'PE', 'sunrise': 1603880864, 'sunset': 1603925963}, 'timezone': -18000, 'id': 3939470, 'name': 'Huancavelica', 'cod': 200}
# City :  east london
# {'coord': {'lon': 27.91, 'lat': -33.02}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 69.8, 'feels_like': 72.28, 'temp_min': 69.8, 'temp_max': 69.8, 'pressure': 1010, 'humidity': 88}, 'visibility': 10000, 'wind': {'speed': 5.82, 'deg': 60}, 'clouds': {'all': 75}, 'dt': 1603913794, 'sys': {'type': 1, 'id': 1912, 'country': 'ZA', 'sunrise': 1603854762, 'sunset': 1603902680}, 'timezone': 7200, 'id': 1006984, 'name': 'East London', 'cod': 200}
# City :  faanui
# {'coord': {'lon': -151.75, 'lat': -16.48}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 79.88, 'feels_like': 79.75, 'temp_min': 79.88, 'temp_max': 79.88, 'pressure': 1013, 'humidity': 80, 'sea_level': 1013, 'grnd_level': 1005}, 'visibility': 10000, 'wind': {'speed': 16.73, 'deg': 341}, 'clouds': {'all': 13}, 'dt': 1603913796, 'sys': {'country': 'PF', 'sunrise': 1603899053, 'sunset': 1603944623}, 'timezone': -36000, 'id': 4034551, 'name': 'Faanui', 'cod': 200}
# City :  rikitea
# {'coord': {'lon': -134.97, 'lat': -23.12}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 74.75, 'feels_like': 74.25, 'temp_min': 74.75, 'temp_max': 74.75, 'pressure': 1017, 'humidity': 83, 'sea_level': 1017, 'grnd_level': 1014}, 'visibility': 10000, 'wind': {'speed': 13.76, 'deg': 323}, 'clouds': {'all': 49}, 'dt': 1603913635, 'sys': {'country': 'PF', 'sunrise': 1603894586, 'sunset': 1603941035}, 'timezone': -32400, 'id': 4030556, 'name': 'Rikitea', 'cod': 200}
# City :  punta arenas
# {'coord': {'lon': -70.92, 'lat': -53.15}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 50, 'feels_like': 33.93, 'temp_min': 50, 'temp_max': 50, 'pressure': 1004, 'humidity': 65}, 'visibility': 10000, 'wind': {'speed': 24.16, 'deg': 270, 'gust': 35.57}, 'clouds': {'all': 75}, 'dt': 1603913701, 'sys': {'type': 1, 'id': 8487, 'country': 'CL', 'sunrise': 1603876053, 'sunset': 1603928826}, 'timezone': -10800, 'id': 3874787, 'name': 'Punta Arenas', 'cod': 200}
# City :  sept-iles
# {'coord': {'lon': -66.38, 'lat': 50.2}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 30.52, 'feels_like': 22.66, 'temp_min': 30.2, 'temp_max': 30.99, 'pressure': 1013, 'humidity': 58}, 'visibility': 10000, 'wind': {'speed': 4.7, 'deg': 210}, 'clouds': {'all': 75}, 'dt': 1603913656, 'sys': {'type': 1, 'id': 1013, 'country': 'CA', 'sunrise': 1603883383, 'sunset': 1603919317}, 'timezone': -14400, 'id': 6144312, 'name': 'Sept-Îles', 'cod': 200}
# City :  uvalde
# {'coord': {'lon': -99.77, 'lat': 29.37}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 62.62, 'feels_like': 53.13, 'temp_min': 60.8, 'temp_max': 64, 'pressure': 1015, 'humidity': 36}, 'visibility': 10000, 'wind': {'speed': 11.41, 'deg': 320, 'gust': 20.8}, 'clouds': {'all': 1}, 'dt': 1603913800, 'sys': {'type': 1, 'id': 6147, 'country': 'US', 'sunrise': 1603889370, 'sunset': 1603929356}, 'timezone': -18000, 'id': 4738723, 'name': 'Uvalde', 'cod': 200}
# City :  bluff
# {'coord': {'lon': 168.33, 'lat': -46.6}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 48.99, 'feels_like': 46.13, 'temp_min': 48.99, 'temp_max': 48.99, 'pressure': 1026, 'humidity': 86}, 'visibility': 10000, 'wind': {'speed': 3, 'deg': 98, 'gust': 8.01}, 'clouds': {'all': 100}, 'dt': 1603913635, 'sys': {'type': 3, 'id': 2008959, 'country': 'NZ', 'sunrise': 1603905995, 'sunset': 1603956842}, 'timezone': 46800, 'id': 2206939, 'name': 'Bluff', 'cod': 200}
# City :  east hartford
# {'coord': {'lon': -72.61, 'lat': 41.78}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 49.64, 'feels_like': 46.71, 'temp_min': 48.99, 'temp_max': 50, 'pressure': 1014, 'humidity': 81}, 'visibility': 10000, 'wind': {'speed': 2.77, 'deg': 222}, 'clouds': {'all': 90}, 'dt': 1603913803, 'sys': {'type': 1, 'id': 3411, 'country': 'US', 'sunrise': 1603883899, 'sunset': 1603921791}, 'timezone': -14400, 'id': 4833403, 'name': 'East Hartford', 'cod': 200}
# City :  bandiagara
# {'coord': {'lon': -3.61, 'lat': 14.35}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 89.6, 'feels_like': 93.54, 'temp_min': 89.6, 'temp_max': 89.6, 'pressure': 1010, 'humidity': 49}, 'visibility': 10000, 'wind': {'speed': 4.7, 'deg': 220}, 'clouds': {'all': 0}, 'dt': 1603913804, 'sys': {'type': 1, 'id': 2362, 'country': 'ML', 'sunrise': 1603865304, 'sunset': 1603907267}, 'timezone': 0, 'id': 2460489, 'name': 'Bandiagara', 'cod': 200}
# City :  airai
# {'coord': {'lon': 125.41, 'lat': -8.93}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 59.77, 'feels_like': 59.43, 'temp_min': 59.77, 'temp_max': 59.77, 'pressure': 1011, 'humidity': 78, 'sea_level': 1011, 'grnd_level': 855}, 'visibility': 10000, 'wind': {'speed': 2.21, 'deg': 53}, 'clouds': {'all': 67}, 'dt': 1603913806, 'sys': {'country': 'TL', 'sunrise': 1603919393, 'sunset': 1603964045}, 'timezone': 32400, 'id': 1651810, 'name': 'Airai', 'cod': 200}
# City :  leningradskiy
# {'coord': {'lon': 178.42, 'lat': 69.38}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 18.46, 'feels_like': 8.78, 'temp_min': 18.46, 'temp_max': 18.46, 'pressure': 1024, 'humidity': 92, 'sea_level': 1024, 'grnd_level': 1024}, 'visibility': 10000, 'wind': {'speed': 7.78, 'deg': 244}, 'clouds': {'all': 100}, 'dt': 1603913723, 'sys': {'country': 'RU', 'sunrise': 1603916119, 'sunset': 1603941875}, 'timezone': 43200, 'id': 2123814, 'name': 'Leningradskiy', 'cod': 200}
# City :  korla
# {'coord': {'lon': 86.15, 'lat': 41.76}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 48.99, 'feels_like': 44.67, 'temp_min': 48.99, 'temp_max': 48.99, 'pressure': 993, 'humidity': 57}, 'visibility': 10000, 'wind': {'speed': 1.99, 'deg': 261, 'gust': 5.99}, 'clouds': {'all': 3}, 'dt': 1603913808, 'sys': {'type': 3, 'id': 2002074, 'country': 'CN', 'sunrise': 1603932235, 'sunset': 1603970046}, 'timezone': 28800, 'id': 1529376, 'name': 'Korla', 'cod': 200}
# City :  dalvik
# {'coord': {'lon': -18.53, 'lat': 65.97}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 41, 'feels_like': 27.61, 'temp_min': 41, 'temp_max': 41, 'pressure': 992, 'humidity': 80}, 'visibility': 10000, 'wind': {'speed': 18.34, 'deg': 80, 'gust': 29.97}, 'clouds': {'all': 40}, 'dt': 1603913809, 'sys': {'type': 1, 'id': 83, 'country': 'IS', 'sunrise': 1603875356, 'sunset': 1603904377}, 'timezone': 0, 'id': 2632287, 'name': 'Dalvik', 'cod': 200}
# City :  chuy
# {'coord': {'lon': -53.46, 'lat': -33.7}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 67.41, 'feels_like': 65.59, 'temp_min': 67.41, 'temp_max': 67.41, 'pressure': 1006, 'humidity': 85, 'sea_level': 1006, 'grnd_level': 1004}, 'visibility': 10000, 'wind': {'speed': 10.92, 'deg': 179}, 'rain': {'1h': 0.12}, 'clouds': {'all': 73}, 'dt': 1603913635, 'sys': {'country': 'UY', 'sunrise': 1603874220, 'sunset': 1603922279}, 'timezone': -10800, 'id': 3443061, 'name': 'Chui', 'cod': 200}
# City :  beringovskiy
# {'coord': {'lon': 179.32, 'lat': 63.05}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 25.48, 'feels_like': 13.75, 'temp_min': 25.48, 'temp_max': 25.48, 'pressure': 1026, 'humidity': 94, 'sea_level': 1026, 'grnd_level': 1024}, 'visibility': 10000, 'wind': {'speed': 12.68, 'deg': 327}, 'clouds': {'all': 70}, 'dt': 1603913812, 'sys': {'country': 'RU', 'sunrise': 1603913399, 'sunset': 1603944162}, 'timezone': 43200, 'id': 2126710, 'name': 'Beringovskiy', 'cod': 200}
# City :  ponta do sol
# {'coord': {'lon': -17.1, 'lat': 32.67}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 64.42, 'feels_like': 62.13, 'temp_min': 60.01, 'temp_max': 68, 'pressure': 1023, 'humidity': 72}, 'visibility': 10000, 'wind': {'speed': 6.93, 'deg': 20}, 'clouds': {'all': 40}, 'dt': 1603913813, 'sys': {'type': 1, 'id': 6894, 'country': 'PT', 'sunrise': 1603869767, 'sunset': 1603909279}, 'timezone': 0, 'id': 2264557, 'name': 'Ponta do Sol', 'cod': 200}
# City :  lebu
# {'coord': {'lon': -73.65, 'lat': -37.62}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 53.71, 'feels_like': 41.88, 'temp_min': 53.71, 'temp_max': 53.71, 'pressure': 1026, 'humidity': 65, 'sea_level': 1026, 'grnd_level': 1015}, 'visibility': 10000, 'wind': {'speed': 17.85, 'deg': 186}, 'clouds': {'all': 0}, 'dt': 1603913814, 'sys': {'country': 'CL', 'sunrise': 1603878705, 'sunset': 1603927484}, 'timezone': -10800, 'id': 3883457, 'name': 'Lebu', 'cod': 200}
# City :  te anau
# {'coord': {'lon': 167.72, 'lat': -45.42}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 49.71, 'feels_like': 48.24, 'temp_min': 49.71, 'temp_max': 49.71, 'pressure': 1023, 'humidity': 84, 'sea_level': 1023, 'grnd_level': 996}, 'visibility': 10000, 'wind': {'speed': 0.58, 'deg': 108}, 'clouds': {'all': 90}, 'dt': 1603913815, 'sys': {'country': 'NZ', 'sunrise': 1603906293, 'sunset': 1603956836}, 'timezone': 46800, 'id': 2181625, 'name': 'Te Anau', 'cod': 200}
# City :  utiroa
# {'cod': '404', 'message': 'city not found'}
# City not found
# City :  chongwe
# {'coord': {'lon': 28.68, 'lat': -15.33}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 77, 'feels_like': 72.61, 'temp_min': 77, 'temp_max': 77, 'pressure': 1018, 'humidity': 25}, 'visibility': 10000, 'wind': {'speed': 3.36, 'deg': 130}, 'clouds': {'all': 0}, 'dt': 1603913647, 'sys': {'type': 1, 'id': 2113, 'country': 'ZM', 'sunrise': 1603855836, 'sunset': 1603901237}, 'timezone': 7200, 'id': 917688, 'name': 'Chongwe', 'cod': 200}
# City :  robertsport
# {'coord': {'lon': -11.37, 'lat': 6.75}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 80.67, 'feels_like': 84.96, 'temp_min': 80.67, 'temp_max': 80.67, 'pressure': 1011, 'humidity': 83, 'sea_level': 1011, 'grnd_level': 1004}, 'visibility': 10000, 'wind': {'speed': 10.78, 'deg': 201}, 'clouds': {'all': 100}, 'dt': 1603913818, 'sys': {'country': 'LR', 'sunrise': 1603866726, 'sunset': 1603909570}, 'timezone': 0, 'id': 2274275, 'name': 'Robertsport', 'cod': 200}
# City :  tshikapa
# {'coord': {'lon': 20.8, 'lat': -6.42}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 72.57, 'feels_like': 79.3, 'temp_min': 72.57, 'temp_max': 72.57, 'pressure': 1011, 'humidity': 93, 'sea_level': 1011, 'grnd_level': 960}, 'visibility': 10000, 'wind': {'speed': 1.99, 'deg': 6}, 'clouds': {'all': 100}, 'dt': 1603913820, 'sys': {'country': 'CD', 'sunrise': 1603858257, 'sunset': 1603902598}, 'timezone': 7200, 'id': 204953, 'name': 'Tshikapa', 'cod': 200}
# City :  nouadhibou
# {'coord': {'lon': -17.03, 'lat': 20.93}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 77, 'feels_like': 72.55, 'temp_min': 77, 'temp_max': 77, 'pressure': 1015, 'humidity': 53}, 'visibility': 6000, 'wind': {'speed': 12.75, 'deg': 360}, 'clouds': {'all': 100}, 'dt': 1603913821, 'sys': {'type': 1, 'id': 2444, 'country': 'MR', 'sunrise': 1603868930, 'sunset': 1603910083}, 'timezone': 0, 'id': 2377457, 'name': 'Nouadhibou', 'cod': 200}
# City :  puerto maldonado
# {'coord': {'lon': -69.18, 'lat': -12.6}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 84.2, 'feels_like': 88.43, 'temp_min': 84.2, 'temp_max': 84.2, 'pressure': 1003, 'humidity': 70}, 'visibility': 10000, 'wind': {'speed': 9.17, 'deg': 280}, 'clouds': {'all': 20}, 'dt': 1603913822, 'sys': {'type': 1, 'id': 8684, 'country': 'PE', 'sunrise': 1603879483, 'sunset': 1603924561}, 'timezone': -18000, 'id': 3931470, 'name': 'Puerto Maldonado', 'cod': 200}
# City :  san quintin
# {'coord': {'lon': -115.95, 'lat': 30.48}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 71.47, 'feels_like': 63.12, 'temp_min': 71.47, 'temp_max': 71.47, 'pressure': 1017, 'humidity': 25, 'sea_level': 1017, 'grnd_level': 1016}, 'visibility': 10000, 'wind': {'speed': 8.97, 'deg': 262}, 'clouds': {'all': 0}, 'dt': 1603913637, 'sys': {'country': 'MX', 'sunrise': 1603893337, 'sunset': 1603933155}, 'timezone': -25200, 'id': 3984997, 'name': 'San Quintín', 'cod': 200}
# City :  taybad
# {'coord': {'lon': 60.78, 'lat': 34.74}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 41.34, 'feels_like': 32.79, 'temp_min': 41.34, 'temp_max': 41.34, 'pressure': 1030, 'humidity': 65, 'sea_level': 1030, 'grnd_level': 933}, 'visibility': 10000, 'wind': {'speed': 8.43, 'deg': 5}, 'clouds': {'all': 0}, 'dt': 1603913825, 'sys': {'country': 'IR', 'sunrise': 1603851229, 'sunset': 1603890436}, 'timezone': 12600, 'id': 1159384, 'name': 'Tāybād', 'cod': 200}
# City :  nizhneyansk
# {'cod': '404', 'message': 'city not found'}
# City not found
# City :  mys shmidta
# {'cod': '404', 'message': 'city not found'}
# City not found
# City :  albuquerque
# {'coord': {'lon': -106.65, 'lat': 35.08}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 40.55, 'feels_like': 31.46, 'temp_min': 37.99, 'temp_max': 43, 'pressure': 1018, 'humidity': 52}, 'visibility': 10000, 'wind': {'speed': 8.05, 'deg': 10}, 'clouds': {'all': 75}, 'dt': 1603913561, 'sys': {'type': 1, 'id': 3205, 'country': 'US', 'sunrise': 1603891466, 'sunset': 1603930562}, 'timezone': -21600, 'id': 5454711, 'name': 'Albuquerque', 'cod': 200}
# City :  huntingdon
# {'coord': {'lon': -0.19, 'lat': 52.33}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 46.42, 'feels_like': 39.56, 'temp_min': 46, 'temp_max': 46.99, 'pressure': 1001, 'humidity': 85}, 'visibility': 10000, 'wind': {'speed': 8.99, 'deg': 221, 'gust': 15.01}, 'clouds': {'all': 58}, 'dt': 1603913830, 'sys': {'type': 3, 'id': 2011271, 'country': 'GB', 'sunrise': 1603867783, 'sunset': 1603903147}, 'timezone': 0, 'id': 2646393, 'name': 'Huntingdon', 'cod': 200}
# City :  ilulissat
# {'coord': {'lon': -51.1, 'lat': 69.22}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 17.6, 'feels_like': 8.08, 'temp_min': 17.6, 'temp_max': 17.6, 'pressure': 997, 'humidity': 48}, 'visibility': 10000, 'wind': {'speed': 5.82, 'deg': 80}, 'clouds': {'all': 40}, 'dt': 1603913831, 'sys': {'type': 1, 'id': 165, 'country': 'GL', 'sunrise': 1603884620, 'sunset': 1603910745}, 'timezone': -10800, 'id': 3423146, 'name': 'Ilulissat', 'cod': 200}
# City :  beohari
# {'coord': {'lon': 81.38, 'lat': 24.05}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 66.11, 'feels_like': 63.12, 'temp_min': 66.11, 'temp_max': 66.11, 'pressure': 1013, 'humidity': 49, 'sea_level': 1013, 'grnd_level': 971}, 'visibility': 10000, 'wind': {'speed': 3.83, 'deg': 145}, 'clouds': {'all': 0}, 'dt': 1603913832, 'sys': {'country': 'IN', 'sunrise': 1603931939, 'sunset': 1603972632}, 'timezone': 19800, 'id': 1276455, 'name': 'Beohāri', 'cod': 200}
# City :  kavaratti
# {'coord': {'lon': 72.64, 'lat': 10.57}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 81.75, 'feels_like': 86.61, 'temp_min': 81.75, 'temp_max': 81.75, 'pressure': 1009, 'humidity': 75, 'sea_level': 1009, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 7.76, 'deg': 307}, 'clouds': {'all': 0}, 'dt': 1603913800, 'sys': {'country': 'IN', 'sunrise': 1603933192, 'sunset': 1603975574}, 'timezone': 19800, 'id': 1267390, 'name': 'Kavaratti', 'cod': 200}
# City :  cabo san lucas
# {'coord': {'lon': -109.91, 'lat': 22.89}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 82.63, 'feels_like': 78.49, 'temp_min': 80.6, 'temp_max': 84.99, 'pressure': 1014, 'humidity': 51}, 'visibility': 10000, 'wind': {'speed': 14.99, 'deg': 160}, 'clouds': {'all': 20}, 'dt': 1603913835, 'sys': {'type': 1, 'id': 7151, 'country': 'MX', 'sunrise': 1603891356, 'sunset': 1603932238}, 'timezone': -25200, 'id': 3985710, 'name': 'Cabo San Lucas', 'cod': 200}
# City :  dhidhdhoo
# {'coord': {'lon': 73.1, 'lat': 6.88}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 82.44, 'feels_like': 88.23, 'temp_min': 82.44, 'temp_max': 82.44, 'pressure': 1010, 'humidity': 73, 'sea_level': 1010, 'grnd_level': 1010}, 'visibility': 10000, 'wind': {'speed': 5.97, 'deg': 326}, 'clouds': {'all': 1}, 'dt': 1603913836, 'sys': {'country': 'MV', 'sunrise': 1603932865, 'sunset': 1603975680}, 'timezone': 18000, 'id': 1337612, 'name': 'Dhidhdhoo', 'cod': 200}
# City :  umm durman
# {'cod': '404', 'message': 'city not found'}
# City not found
# City :  sola
# ...
# City :  adeje
# {'coord': {'lon': -16.73, 'lat': 28.12}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 69.89, 'feels_like': 61.27, 'temp_min': 64.99, 'temp_max': 72, 'pressure': 1020, 'humidity': 56}, 'visibility': 10000, 'wind': {'speed': 17.22, 'deg': 60}, 'clouds': {'all': 40}, 'dt': 1603914400, 'sys': {'type': 1, 'id': 2373, 'country': 'ES', 'sunrise': 1603869340, 'sunset': 1603909529}, 'timezone': 0, 'id': 2522437, 'name': 'Adeje', 'cod': 200}
# City :  berlevag
# {'coord': {'lon': 29.09, 'lat': 70.86}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 35.4, 'feels_like': 23.13, 'temp_min': 32, 'temp_max': 37.4, 'pressure': 993, 'humidity': 81}, 'visibility': 10000, 'wind': {'speed': 14.99, 'deg': 230}, 'clouds': {'all': 75}, 'dt': 1603914402, 'sys': {'type': 1, 'id': 1620, 'country': 'NO', 'sunrise': 1603866256, 'sunset': 1603890620}, 'timezone': 3600, 'id': 780687, 'name': 'Berlevåg', 'cod': 200}
# City :  sioux lookout
# {'coord': {'lon': -91.92, 'lat': 50.1}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 26.6, 'feels_like': 17.62, 'temp_min': 26.6, 'temp_max': 26.6, 'pressure': 1012, 'humidity': 73}, 'visibility': 10000, 'wind': {'speed': 6.93, 'deg': 360}, 'clouds': {'all': 90}, 'dt': 1603914345, 'sys': {'type': 1, 'id': 979, 'country': 'CA', 'sunrise': 1603889506, 'sunset': 1603925453}, 'timezone': -18000, 'id': 6148373, 'name': 'Sioux Lookout', 'cod': 200}
# City :  qunduz
# {'coord': {'lon': 68.86, 'lat': 36.73}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 45.18, 'feels_like': 38.75, 'temp_min': 45.18, 'temp_max': 45.18, 'pressure': 1030, 'humidity': 43, 'sea_level': 1030, 'grnd_level': 981}, 'visibility': 10000, 'wind': {'speed': 3.27, 'deg': 216}, 'clouds': {'all': 0}, 'dt': 1603914404, 'sys': {'country': 'AF', 'sunrise': 1603935914, 'sunset': 1603974666}, 'timezone': 16200, 'id': 1135689, 'name': 'Kunduz', 'cod': 200}
# City :  lerwick
# {'coord': {'lon': -1.15, 'lat': 60.15}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 50, 'feels_like': 43.54, 'temp_min': 50, 'temp_max': 50, 'pressure': 988, 'humidity': 81}, 'visibility': 10000, 'wind': {'speed': 9.17, 'deg': 240}, 'clouds': {'all': 75}, 'dt': 1603914405, 'sys': {'type': 1, 'id': 1438, 'country': 'GB', 'sunrise': 1603869471, 'sunset': 1603901920}, 'timezone': 0, 'id': 2644605, 'name': 'Lerwick', 'cod': 200}
# City :  kloulklubed
# {'coord': {'lon': 134.26, 'lat': 7.04}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 77, 'feels_like': 81.61, 'temp_min': 77, 'temp_max': 77, 'pressure': 1008, 'humidity': 94}, 'visibility': 10000, 'wind': {'speed': 10.33, 'deg': 211}, 'clouds': {'all': 75}, 'dt': 1603914406, 'sys': {'type': 1, 'id': 7901, 'country': 'PW', 'sunrise': 1603918195, 'sunset': 1603960994}, 'timezone': 32400, 'id': 7671223, 'name': 'Kloulklubed', 'cod': 200}
# City :  zarubino
# {'coord': {'lon': 131.09, 'lat': 42.63}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 38.41, 'feels_like': 26.98, 'temp_min': 38.41, 'temp_max': 38.41, 'pressure': 1024, 'humidity': 71, 'sea_level': 1024, 'grnd_level': 1014}, 'visibility': 10000, 'wind': {'speed': 13.4, 'deg': 308}, 'clouds': {'all': 0}, 'dt': 1603914407, 'sys': {'country': 'RU', 'sunrise': 1603921530, 'sunset': 1603959181}, 'timezone': 36000, 'id': 2012646, 'name': 'Zarubino', 'cod': 200}
# City :  sao mateus do maranhao
# {'coord': {'lon': -44.48, 'lat': -4.04}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 89.2, 'feels_like': 95.07, 'temp_min': 89.2, 'temp_max': 89.2, 'pressure': 1005, 'humidity': 54, 'sea_level': 1005, 'grnd_level': 1000}, 'visibility': 10000, 'wind': {'speed': 3.44, 'deg': 290}, 'clouds': {'all': 92}, 'dt': 1603914408, 'sys': {'country': 'BR', 'sunrise': 1603874059, 'sunset': 1603918129}, 'timezone': -10800, 'id': 3388318, 'name': 'São Mateus do Maranhão', 'cod': 200}
# City :  hays
# {'coord': {'lon': -98.03, 'lat': 30.05}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 58.69, 'feels_like': 52.03, 'temp_min': 57, 'temp_max': 61, 'pressure': 1010, 'humidity': 56}, 'visibility': 10000, 'wind': {'speed': 8.99, 'deg': 24, 'gust': 15.99}, 'clouds': {'all': 0}, 'dt': 1603914409, 'sys': {'type': 3, 'id': 2006821, 'country': 'US', 'sunrise': 1603889002, 'sunset': 1603928889}, 'timezone': -18000, 'id': 4696788, 'name': 'Hays', 'cod': 200}
# City :  meyungs
# {'cod': '404', 'message': 'city not found'}
# City not found
# City :  cayenne
# {'coord': {'lon': -52.33, 'lat': 4.93}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 87.8, 'feels_like': 89.91, 'temp_min': 87.8, 'temp_max': 87.8, 'pressure': 1006, 'humidity': 62}, 'visibility': 10000, 'wind': {'speed': 12.75, 'deg': 90}, 'clouds': {'all': 40}, 'dt': 1603914186, 'sys': {'type': 1, 'id': 8669, 'country': 'GF', 'sunrise': 1603876453, 'sunset': 1603919503}, 'timezone': -10800, 'id': 3382160, 'name': 'Cayenne', 'cod': 200}
# City :  glushkovo
# {'coord': {'lon': 34.63, 'lat': 51.34}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 44.24, 'feels_like': 37.44, 'temp_min': 44.24, 'temp_max': 44.24, 'pressure': 1023, 'humidity': 81, 'sea_level': 1023, 'grnd_level': 1005}, 'visibility': 10000, 'wind': {'speed': 7.72, 'deg': 129}, 'clouds': {'all': 0}, 'dt': 1603914413, 'sys': {'country': 'RU', 'sunrise': 1603859271, 'sunset': 1603894946}, 'timezone': 10800, 'id': 560995, 'name': 'Glushkovo', 'cod': 200}
# City :  tansen
# {'coord': {'lon': 83.55, 'lat': 27.87}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 53.74, 'feels_like': 51.01, 'temp_min': 53.74, 'temp_max': 53.74, 'pressure': 1016, 'humidity': 85, 'sea_level': 1016, 'grnd_level': 860}, 'visibility': 10000, 'wind': {'speed': 4.68, 'deg': 4}, 'clouds': {'all': 0}, 'dt': 1603914414, 'sys': {'country': 'NP', 'sunrise': 1603931685, 'sunset': 1603971845}, 'timezone': 20700, 'id': 1282714, 'name': 'Tānsen', 'cod': 200}
# City :  zlatoustovsk
# {'cod': '404', 'message': 'city not found'}
# City not found
# City :  diffa
# {'coord': {'lon': 12.61, 'lat': 13.32}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 82.85, 'feels_like': 75.76, 'temp_min': 82.85, 'temp_max': 82.85, 'pressure': 1010, 'humidity': 17, 'sea_level': 1010, 'grnd_level': 976}, 'visibility': 10000, 'wind': {'speed': 6.67, 'deg': 45}, 'clouds': {'all': 0}, 'dt': 1603914416, 'sys': {'country': 'NE', 'sunrise': 1603861350, 'sunset': 1603903436}, 'timezone': 3600, 'id': 2445704, 'name': 'Diffa', 'cod': 200}
# City :  maltahohe
# {'coord': {'lon': 16.98, 'lat': -24.83}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 74.77, 'feels_like': 64.83, 'temp_min': 74.77, 'temp_max': 74.77, 'pressure': 1012, 'humidity': 20, 'sea_level': 1012, 'grnd_level': 869}, 'visibility': 10000, 'wind': {'speed': 11.03, 'deg': 206}, 'clouds': {'all': 95}, 'dt': 1603914417, 'sys': {'country': 'NA', 'sunrise': 1603858016, 'sunset': 1603904673}, 'timezone': 7200, 'id': 3355624, 'name': 'Maltahöhe', 'cod': 200}
# City :  nekhayevskiy
# {'coord': {'lon': 41.76, 'lat': 50.41}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 37, 'feels_like': 27.16, 'temp_min': 37, 'temp_max': 37, 'pressure': 1016, 'humidity': 57}, 'visibility': 10000, 'wind': {'speed': 9.17, 'deg': 118}, 'clouds': {'all': 0}, 'dt': 1603914418, 'sys': {'type': 3, 'id': 2016483, 'country': 'RU', 'sunrise': 1603857427, 'sunset': 1603893367}, 'timezone': 14400, 'id': 522902, 'name': 'Nekhayevskiy', 'cod': 200}
# City :  viedma
# {'coord': {'lon': -63, 'lat': -40.81}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 60.01, 'feels_like': 53.44, 'temp_min': 60.01, 'temp_max': 60.01, 'pressure': 1016, 'humidity': 49}, 'visibility': 10000, 'wind': {'speed': 8.01, 'deg': 180, 'gust': 24}, 'clouds': {'all': 95}, 'dt': 1603914420, 'sys': {'type': 3, 'id': 2030260, 'country': 'AR', 'sunrise': 1603875829, 'sunset': 1603925248}, 'timezone': -10800, 'id': 3832899, 'name': 'Viedma', 'cod': 200}
# City :  havre
# {'coord': {'lon': 0.33, 'lat': 49.58}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 52.14, 'feels_like': 35.44, 'temp_min': 51.01, 'temp_max': 53.6, 'pressure': 1009, 'humidity': 76}, 'visibility': 10000, 'wind': {'speed': 27.51, 'deg': 260, 'gust': 41.38}, 'rain': {'1h': 1}, 'clouds': {'all': 100}, 'dt': 1603914193, 'sys': {'type': 1, 'id': 6533, 'country': 'FR', 'sunrise': 1603867270, 'sunset': 1603903410}, 'timezone': 3600, 'id': 3013633, 'name': 'Arrondissement du Havre', 'cod': 200}
# City :  araouane
# {'coord': {'lon': -3.53, 'lat': 18.9}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 90.14, 'feels_like': 82.27, 'temp_min': 90.14, 'temp_max': 90.14, 'pressure': 1013, 'humidity': 14, 'sea_level': 1013, 'grnd_level': 982}, 'visibility': 10000, 'wind': {'speed': 8.3, 'deg': 8}, 'clouds': {'all': 53}, 'dt': 1603914422, 'sys': {'country': 'ML', 'sunrise': 1603865561, 'sunset': 1603906972}, 'timezone': 0, 'id': 2460954, 'name': 'Araouane', 'cod': 200}
# City :  ruatoria
# {'cod': '404', 'message': 'city not found'}
# City not found
# City :  raudeberg
# {'coord': {'lon': 5.14, 'lat': 61.99}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 46.99, 'feels_like': 33.13, 'temp_min': 46.99, 'temp_max': 46.99, 'pressure': 985, 'humidity': 79}, 'visibility': 10000, 'wind': {'speed': 20.94, 'deg': 94}, 'rain': {'1h': 1.43}, 'clouds': {'all': 100}, 'dt': 1603914424, 'sys': {'type': 3, 'id': 2003008, 'country': 'NO', 'sunrise': 1603868417, 'sunset': 1603899955}, 'timezone': 3600, 'id': 3146487, 'name': 'Raudeberg', 'cod': 200}
# City :  dawson creek
# {'coord': {'lon': -120.24, 'lat': 55.77}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 44.6, 'feels_like': 34.29, 'temp_min': 44.6, 'temp_max': 44.6, 'pressure': 1014, 'humidity': 45}, 'visibility': 10000, 'wind': {'speed': 10.29, 'deg': 270, 'gust': 17.22}, 'clouds': {'all': 1}, 'dt': 1603914425, 'sys': {'type': 1, 'id': 783, 'country': 'CA', 'sunrise': 1603897200, 'sunset': 1603931351}, 'timezone': -25200, 'id': 5935804, 'name': 'Dawson Creek', 'cod': 200}
# City :  whitehorse
# {'coord': {'lon': -135.05, 'lat': 60.72}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13d'}], 'base': 'stations', 'main': {'temp': 28.38, 'feels_like': 18.72, 'temp_min': 28, 'temp_max': 28.99, 'pressure': 1012, 'humidity': 86}, 'visibility': 2414, 'wind': {'speed': 9.17, 'deg': 340}, 'clouds': {'all': 90}, 'dt': 1603914167, 'sys': {'type': 1, 'id': 983, 'country': 'CA', 'sunrise': 1603901802, 'sunset': 1603933858}, 'timezone': -25200, 'id': 6180550, 'name': 'Whitehorse', 'cod': 200}
# ['Upernavik', 'Iqaluit', 'Talnakh', 'Sterlibashevo', 'Albany', 'Kapaa', 'Dikson', 'Ushuaia', 'Saskylakh', 'Lipin Bor', 'Portland', 'Sena Madureira', 'Atuona', 'Mataura', 'Broken Hill', 'Jamestown', 'Mwanza', 'Hithadhoo', 'Arraial do Cabo', 'Changji', 'Tuatapere', 'Hilo', 'Hermanus', 'Lagoa', 'Guerrero Negro', 'Busselton', 'Bredasdorp', 'New Norfolk', 'George Town', 'Vaini', 'Tuktoyaktuk', 'Srednekolymsk', 'Cape Town', 'Marsh Harbour', 'Castro', 'Yellowknife', 'Quang Ngai', 'São Filipe', 'Poum', 'Tiksi', 'Wajid', 'Jaru', 'Kaitangata', 'Aklavik', 'Nikolskoye', 'Novoagansk', 'Ifanadiana', 'Changying', 'Avarua', 'Saint-François', 'Cherskiy', 'Huancavelica', 'East London', 'Faanui', 'Rikitea', 'Punta Arenas', 'Sept-Îles', 'Uvalde', 'Bluff', 'East Hartford', 'Bandiagara', 'Airai', 'Leningradskiy', 'Korla', 'Dalvik', 'Chui', 'Beringovskiy', 'Ponta do Sol', 'Lebu', 'Te Anau', 'Chongwe', 'Robertsport', 'Tshikapa', 'Nouadhibou', 'Puerto Maldonado', 'San Quintín', 'Tāybād', 'Albuquerque', 'Huntingdon', 'Ilulissat', 'Beohāri', 'Kavaratti', 'Cabo San Lucas', 'Dhidhdhoo', 'Sola', 'Caravelas', 'Mahébourg', 'Khatanga', 'Ribeira Grande', 'Raja', 'Vardø', 'San Cristobal', 'Hobart', 'Lavrentiya', 'Port Alfred', 'Ginda', 'Zanesville', 'Puerto Ayora', 'Fomboni', 'Uvinza', 'Saint Paul Harbor', 'Sittwe', 'Tagusao', 'Walvis Bay', 'Hualmay', 'Chokurdakh', 'Alofi', 'Mar del Plata', 'Itarema', 'Provideniya', 'Constitución', 'Kenai', 'Xudat', 'Kavieng', 'Porto-Novo', 'Lanigan', 'Klaksvík', 'Nokha', 'Nuevitas', 'Sørland', 'Hasaki', 'Semey', 'Shawnee', 'Phang Nga', 'Matagami', 'Acopiara', 'Nome', 'Ahipara', 'Sitka', 'Carutapera', 'Mehamn', 'Lokoja', 'Betsiamites', 'Cheremshanka', 'São Gabriel da Cachoeira', 'Salalah', 'Borodino', 'Eureka', 'Esmeraldas', 'Narganá', 'Birjand', 'Doumé', 'Honiara', 'Shingū', 'Labuhan', 'Bengkulu', 'Port Hardy', 'Kahului', 'Sinnamary', 'Butaritari', 'Half Moon Bay', 'Gamba', 'Rovaniemi', 'Thompson', 'Champerico', 'Navrongo', 'Baracoa', 'Misratah', 'Port Lincoln', 'Cidreira', 'Tongliao', 'Chitral', 'Pevek', 'Torbay', 'Hokitika', 'Carnarvon', 'Mezhdurechenskiy', 'Homer', 'Bathsheba', 'Norman Wells', 'Antofagasta', 'Barrow', 'Chuguyevka', 'Ponta Delgada', 'Kabare', 'Channel-Port aux Basques', 'Kamaishi', 'West Bay', 'Hambantota', 'Sur', 'Ostrovnoy', 'Cap Malheureux', 'Pisco', 'Tasiilaq', 'Vanavara', 'Bambous Virieux', 'Hunchun', 'Mossamedes', 'Sal Rei', 'Porto Torres', 'Puyang', 'Alice Springs', 'Aswān', 'Cockburn Town', 'Asău', 'Esperance', 'Hohhot', 'Mt. Pleasant', 'Thinadhoo', 'Tura', 'Jaqué', 'Price', 'Sovetsk', 'Coquimbo', 'Leshukonskoye', 'Zaykovo', 'Saint Anthony', 'Kirakira', 'Healdsburg', 'Geraldton', 'Dom Pedrito', 'Port Elizabeth', 'Fortuna', 'Luau', 'Sokoni', 'Tarko-Sale', 'Sydney', 'Saint-Philippe', 'Aitape', 'Falun', 'Svetlaya', 'Wad Medani', 'Strezhevoy', 'Nerchinskiy Zavod', 'Vitim', 'Laas', 'Longyearbyen', 'Waddān', 'Gunjur', 'Boa Vista', 'Santa Cruz de la Sierra', 'Nanortalik', 'Grenå', 'Souillac', 'Moerai', 'Vaitape', 'Iskateley', 'Iralaya', '‘Ewa Beach', 'Bethel', 'Makaha', 'Beloha', 'Aksu', 'Lovozero', 'Verāval', 'Guarapari', 'Naryan-Mar', 'Griffith', 'Straumen', 'Fairbanks', 'Mpika', 'Brae', 'Broome', 'Tiarei', 'Adrar', 'Buraidah', 'Winnemucca', 'Pangnirtung', 'Mthatha', 'Nazca', 'Coffs Harbour', 'Xam Nua', 'Padre Bernardo', 'Xining', 'Nhulunbuy', 'Vanimo', 'Namatanai', 'Hirara', 'Winslow', 'Kitami', 'Abéché', 'Lüderitz', 'Vestmannaeyjar', 'Lata', 'Boshnyakovo', 'Bocanda', "Severo-Kuril'sk", 'Bath', 'College', 'Port Hawkesbury', 'Muisne', 'Mount Gambier', 'Kannur', 'Boo', 'Fare', 'São João da Barra', 'Ugoofaaru', 'Guayaramerín', 'Tupik', 'Teya', 'Voh', 'Provincia di Ancona', 'Dunmore East', 'Quelimane', 'Belmonte', 'Aden', 'Borås', 'Vestmanna', 'Saint George', 'Yerbogachën', 'Zhigansk', 'Grindavik', 'Kiunga', 'Bandarbeyla', 'Naze', 'Kibala', 'Taoudenni', 'Ingham', 'Ransang', 'Collie', 'Maniitsoq', 'Gizo Government Station', 'Suntar', 'Chiredzi', 'Coyhaique', 'Luang Prabang', 'Sharan', 'Fort Nelson', 'Kudahuva ...

# %%
# Get data from csv file
data = requests.get(query_url).json()
data
# Out:
# {'coord': {'lon': -135.05, 'lat': 60.72},
#  'weather': [{'id': 600,
#    'main': 'Snow',
#    'description': 'light snow',
#    'icon': '13d'}],
#  'base': 'stations',
#  'main': {'temp': 28.38,
#   'feels_like': 18.72,
#   'temp_min': 28,
#   'temp_max': 28.99,
#   'pressure': 1012,
#   'humidity': 86},
#  'visibility': 2414,
#  'wind': {'speed': 9.17, 'deg': 340},
#  'clouds': {'all': 90},
#  'dt': 1603914167,
#  'sys': {'type': 1,
#   'id': 983,
#   'country': 'CA',
#   'sunrise': 1603901802,
#   'sunset': 1603933858},
#  'timezone': -25200,
#  'id': 6180550,
#  'name': 'Whitehorse',
#  'cod': 200}

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Create DF
city_weather_df = pd.DataFrame({
    'city' : city_name,
    'Lat' : Lat,
    'Long' :Long,
    'MaxTemp' : MaxTemp,
    'Humidity' : Humidity,
    'Cloundiness' : Cloundiness,
    'Wind Speed' : WindSpeed 
})



city_weather_df.to_csv("cities.csv", index=False)
city_weather_df
# Out:
#                         city    Lat    Long  MaxTemp  Humidity  Cloundiness  \
# 0                  Upernavik  72.79  -56.15    11.98        82            0
# 1                    Iqaluit  63.75  -68.51    17.60        61           90
# 2                    Talnakh  69.49   88.40    -1.97        76            0
# 3              Sterlibashevo  53.44   55.26    31.08        92            6
# 4                     Albany  42.60  -73.97    50.00        88           96
# ..                       ...    ...     ...      ...       ...          ...
# 563  Arrondissement du Havre  49.58    0.33    53.60        76          100
# 564                 Araouane  18.90   -3.53    90.14        14           53
# 565                Raudeberg  61.99    5.14    46.99        79          100
# 566             Dawson Creek  55.77 -120.24    44.60        45            1
# 567               Whitehorse  60.72 -135.05    28.99        86           90
#
#      Wind Speed
# 0          9.13
# 1          9.17
# 2          4.88
# 3          6.22
# 4          1.83
# ..          ...
# 563       27.51
# 564        8.30
# 565       20.94
# 566       10.29
# 567        9.17
#
# [568 rows x 7 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
#city_weather_df.drop(['Humidity'], >= 100)

# CREATE INDEX
index_names = city_weather_df[city_weather_df['Humidity'] > 100 ].index 
# drop these row indexes 
# from dataFrame 
city_clean_data = city_weather_df.drop(index_names, inplace = False) 
  
city_clean_data
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
# Out:
#                         city    Lat    Long  MaxTemp  Humidity  Cloundiness  \
# 0                  Upernavik  72.79  -56.15    11.98        82            0
# 1                    Iqaluit  63.75  -68.51    17.60        61           90
# 2                    Talnakh  69.49   88.40    -1.97        76            0
# 3              Sterlibashevo  53.44   55.26    31.08        92            6
# 4                     Albany  42.60  -73.97    50.00        88           96
# ..                       ...    ...     ...      ...       ...          ...
# 563  Arrondissement du Havre  49.58    0.33    53.60        76          100
# 564                 Araouane  18.90   -3.53    90.14        14           53
# 565                Raudeberg  61.99    5.14    46.99        79          100
# 566             Dawson Creek  55.77 -120.24    44.60        45            1
# 567               Whitehorse  60.72 -135.05    28.99        86           90
#
#      Wind Speed
# 0          9.13
# 1          9.17
# 2          4.88
# 3          6.22
# 4          1.83
# ..          ...
# 563       27.51
# 564        8.30
# 565       20.94
# 566       10.29
# 567        9.17
#
# [568 rows x 7 columns]

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Create Latitude vs. Temperature Plot scatter plot
plt.scatter(city_clean_data["Lat"], city_clean_data["MaxTemp"], facecolor = "lightblue", edgecolor = "black")

# Set title/
plt.title("City Latitude vs. Max Temperature (107/20)")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Max Temperature (F)")

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("../City Latitude vs Max Temperature.png")

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Create Latitude vs. Humnidity Plot scatter plot
plt.scatter(city_clean_data["Lat"],city_clean_data["Humidity"], facecolor = "darkviolet", edgecolor = "black")

# Title/
plt.title("City Latitude vs. Humidity")

# Set xX.xlabel("Laitude")

# Y axis label
plt.ylabel("Humidity (%)")

# Grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save  as .pngs
plt.savefig("../City Latitude vs Humidity.png")

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Create Latitude vs. Cloundiness Plot scatter plot
plt.scatter(city_clean_data["Lat"], city_clean_data["Cloundiness"], facecolor = "deepskyblue", edgecolor = "black")

# Title/
plt.title("City Latitude vs. Cloundiness ")

#X axis label
plt.xlabel("Laitude")

# Y axis label
plt.ylabel("Cloundiness")

# Grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save  as .pngs
plt.savefig("../City Latitude vs Cloudiness.png")

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Create Latitude vs. Wind Speed Plot scatter plot
plt.scatter(city_clean_data["Lat"], city_clean_data["Wind Speed"], facecolor = "steelblue", edgecolor = "black")

# Title/
plt.title("City Latitude vs. Wind Speed ")

#X axis label
plt.xlabel("Laitude")

# Y axis label
plt.ylabel("Wind Speed")

# Grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save  as .pngs
plt.savefig("../City Latitude vs Wind.png")

# %% [markdown]
# ## Linear Regression

# %%
#Define North and south
north = city_clean_data.loc[city_weather_df['Lat'] >= 0]
south = city_clean_data.loc[city_weather_df['Lat'] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Perform a linear regression on temperature vs. latitude
x_values = north['MaxTemp']
y_values = north['Lat']
#city_clean_data.loc[:,("MaxTemp", 'Lat')]
# y = mx + b
result = stats.linregress(x_values, y_values)
slope = result.slope
intercept = result.intercept
rvalue = result.rvalue

print(slope, intercept, rvalue)

# Get regression values
regress_values = x_values * slope + intercept
north['regress Temp'] = regress_values

north
# Out:
# -0.7396735632045977 78.04108110339246 -0.8786824478092693
# C:\Users\jocel\.conda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
#                         city    Lat    Long  MaxTemp  Humidity  Cloundiness  \
# 0                  Upernavik  72.79  -56.15    11.98        82            0
# 1                    Iqaluit  63.75  -68.51    17.60        61           90
# 2                    Talnakh  69.49   88.40    -1.97        76            0
# 3              Sterlibashevo  53.44   55.26    31.08        92            6
# 4                     Albany  42.60  -73.97    50.00        88           96
# ..                       ...    ...     ...      ...       ...          ...
# 563  Arrondissement du Havre  49.58    0.33    53.60        76          100
# 564                 Araouane  18.90   -3.53    90.14        14           53
# 565                Raudeberg  61.99    5.14    46.99        79          100
# 566             Dawson Creek  55.77 -120.24    44.60        45            1
# 567               Whitehorse  60.72 -135.05    28.99        86           90
#
#      Wind Speed  regress Temp
# 0          9.13     69.179792
# 1          9.17     65.022826
# 2          4.88     79.498238
# 3          6.22     55.052027
# 4          1.83     41.057403
# ..          ...           ...
# 563       27.51     38.394578
# 564        8.30     11.366906
# 565       20.94     43.283820
# 566       10.29     45.051640
# 567        9.17     56.597945
#
# [401 rows x 8 columns]

# %%
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, color='red')

plt.xlabel('MaxTemp')
plt.ylabel('Lat')

#y = mx + b
eq = f'y = {round(slope, 2)}x + {round(intercept, 2)}'
r_squared = f'r^2 = {round(rvalue ** 2, 2)}'
plt.title('Northern Hemisphere - Max Temp vs. Latitude Linear Regression')
plt.annotate(eq, (40, 20.5), color='red')
plt.annotate(r_squared, (40, 19), color='red')
plt.savefig("Northern - Max Temp Lat")

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Perform a linear regression on temperature vs. latitude
#x_values = south['MaxTemp']
#y_values = south['Lat']
regress = city_clean_data.loc[:, ('MaxTemp', 'Lat')] 


# y = mx + b
result = stats.linregress(x_values, y_values)
slope = result.slope
intercept = result.intercept
rvalue = result.rvalue

print(slope, intercept, rvalue)

# Get regression values
regress_values = x_values * slope + intercept
south['regress temp'] = regress_values

south
# Out:
# -0.7396735632045977 78.04108110339246 -0.8786824478092693
# C:\Users\jocel\.conda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                        city    Lat    Long  MaxTemp  Humidity  Cloundiness  \
# 7                   Ushuaia -54.80  -68.30    46.40        61           75
# 11           Sena Madureira  -9.07  -68.66    95.05        44           87
# 12                   Atuona  -9.80 -139.03    78.30        67           21
# 13                  Mataura -46.19  168.86    48.99        86          100
# 14              Broken Hill -31.95  141.43    55.40        66           75
# ..                      ...    ...     ...      ...       ...          ...
# 541                   Luena -11.78   19.92    67.82        76          100
# 544               Tchibanga  -2.85   11.03    70.25        98          100
# 554  São Mateus do Maranhão  -4.04  -44.48    89.20        54           92
# 560               Maltahöhe -24.83   16.98    74.77        20           95
# 562                  Viedma -40.81  -63.00    60.01        49           95
#
#      Wind Speed  regress temp
# 7         19.46           NaN
# 11         3.11           NaN
# 12        14.65           NaN
# 13         3.00           NaN
# 14         8.48           NaN
# ..          ...           ...
# 541        2.30           NaN
# 544        2.04           NaN
# 554        3.44           NaN
# 560       11.03           NaN
# 562        8.01           NaN
#
# [167 rows x 8 columns]

# %%
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, color='black')

plt.xlabel('Lat')
plt.ylabel('MaxTemp')

#y = mx + b
eq = f'y = {round(slope, 2)}x + {round(intercept, 2)}'
r_squared = f'r^2 = {round(rvalue ** 2, 2)}'
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression")
plt.annotate(eq, (40, 20.5), color='red')
plt.annotate(r_squared, (40, 19), color='red')
plt.savefig("South - Max Temp Lat")

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Perform a linear regression on temperature vs. latitude
x_values = north['Humidity']
y_values = north['Lat']

# y = mx + b
result = stats.linregress(x_values, y_values)
slope = result.slope
intercept = result.intercept
rvalue = result.rvalue

print(slope, intercept, rvalue)

# Get regression values
regress_values = x_values * slope + intercept
north['regress hum'] = regress_values

north
# Out:
# 0.3001030866681645 16.59897902374943 0.3268920888511654
# C:\Users\jocel\.conda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
#                         city    Lat    Long  MaxTemp  Humidity  Cloundiness  \
# 0                  Upernavik  72.79  -56.15    11.98        82            0
# 1                    Iqaluit  63.75  -68.51    17.60        61           90
# 2                    Talnakh  69.49   88.40    -1.97        76            0
# 3              Sterlibashevo  53.44   55.26    31.08        92            6
# 4                     Albany  42.60  -73.97    50.00        88           96
# ..                       ...    ...     ...      ...       ...          ...
# 563  Arrondissement du Havre  49.58    0.33    53.60        76          100
# 564                 Araouane  18.90   -3.53    90.14        14           53
# 565                Raudeberg  61.99    5.14    46.99        79          100
# 566             Dawson Creek  55.77 -120.24    44.60        45            1
# 567               Whitehorse  60.72 -135.05    28.99        86           90
#
#      Wind Speed  regress Temp  regress hum
# 0          9.13     69.179792    41.207432
# 1          9.17     65.022826    34.905267
# 2          4.88     79.498238    39.406814
# 3          6.22     55.052027    44.208463
# 4          1.83     41.057403    43.008051
# ..          ...           ...          ...
# 563       27.51     38.394578    39.406814
# 564        8.30     11.366906    20.800422
# 565       20.94     43.283820    40.307123
# 566       10.29     45.051640    30.103618
# 567        9.17     56.597945    42.407844
#
# [401 rows x 9 columns]

# %%
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, color='black')

plt.xlabel('Humidity')
plt.ylabel('Lat')

#y = mx + b
eq = f'y = {round(slope, 2)}x + {round(intercept, 2)}'
r_squared = f'r^2 = {round(rvalue ** 2, 2)}'
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression")
plt.annotate(eq, (40, 20.5), color='black')
plt.annotate(r_squared, (40, 19), color='black')
plt.savefig("Northern - Humitity Lat")

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Perform a linear regression on temperature vs. latitude
x_values = south['Humidity']
y_values = south['Lat']

# y = mx + b
result = stats.linregress(x_values, y_values)
slope = result.slope
intercept = result.intercept
rvalue = result.rvalue

print(slope, intercept, rvalue)

# Get regression values
regress_values = x_values * slope + intercept
south['regress hum'] = regress_values

south
# Out:
# 0.01587360348263105 -21.56003276790616 0.02292025971535682
# C:\Users\jocel\.conda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
#                        city    Lat    Long  MaxTemp  Humidity  Cloundiness  \
# 7                   Ushuaia -54.80  -68.30    46.40        61           75
# 11           Sena Madureira  -9.07  -68.66    95.05        44           87
# 12                   Atuona  -9.80 -139.03    78.30        67           21
# 13                  Mataura -46.19  168.86    48.99        86          100
# 14              Broken Hill -31.95  141.43    55.40        66           75
# ..                      ...    ...     ...      ...       ...          ...
# 541                   Luena -11.78   19.92    67.82        76          100
# 544               Tchibanga  -2.85   11.03    70.25        98          100
# 554  São Mateus do Maranhão  -4.04  -44.48    89.20        54           92
# 560               Maltahöhe -24.83   16.98    74.77        20           95
# 562                  Viedma -40.81  -63.00    60.01        49           95
#
#      Wind Speed  regress temp  regress hum
# 7         19.46           NaN   -20.591743
# 11         3.11           NaN   -20.861594
# 12        14.65           NaN   -20.496501
# 13         3.00           NaN   -20.194903
# 14         8.48           NaN   -20.512375
# ..          ...           ...          ...
# 541        2.30           NaN   -20.353639
# 544        2.04           NaN   -20.004420
# 554        3.44           NaN   -20.702858
# 560       11.03           NaN   -21.242561
# 562        8.01           NaN   -20.782226
#
# [167 rows x 9 columns]

# %%
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, color='red')

plt.xlabel('Humidity')
plt.ylabel('Lat')

#y = mx + b
eq = f'y = {round(slope, 2)}x + {round(intercept, 2)}'
r_squared = f'r^2 = {round(rvalue ** 2, 2)}'
plt.title("####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression")
plt.annotate(eq, (40, 20.5), color='red')
plt.annotate(r_squared, (40, 19), color='red')
plt.savefig("South - Humidity Lat")

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Perform a linear regression on temperature vs. latitude
x_values = north['Cloundiness']
y_values = north['Lat']

# y = mx + b
result = stats.linregress(x_values, y_values)
slope = result.slope
intercept = result.intercept
rvalue = result.rvalue

print(slope, intercept, rvalue)

# Get regression values
regress_values = x_values * slope + intercept
north['regress cloud'] = regress_values

north
# Out:
# 0.08237153890377649 34.1847597676668 0.16073813359171044
# C:\Users\jocel\.conda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
#                         city    Lat    Long  MaxTemp  Humidity  Cloundiness  \
# 0                  Upernavik  72.79  -56.15    11.98        82            0
# 1                    Iqaluit  63.75  -68.51    17.60        61           90
# 2                    Talnakh  69.49   88.40    -1.97        76            0
# 3              Sterlibashevo  53.44   55.26    31.08        92            6
# 4                     Albany  42.60  -73.97    50.00        88           96
# ..                       ...    ...     ...      ...       ...          ...
# 563  Arrondissement du Havre  49.58    0.33    53.60        76          100
# 564                 Araouane  18.90   -3.53    90.14        14           53
# 565                Raudeberg  61.99    5.14    46.99        79          100
# 566             Dawson Creek  55.77 -120.24    44.60        45            1
# 567               Whitehorse  60.72 -135.05    28.99        86           90
#
#      Wind Speed  regress Temp  regress hum  regress cloud
# 0          9.13     69.179792    41.207432      34.184760
# 1          9.17     65.022826    34.905267      41.598198
# 2          4.88     79.498238    39.406814      34.184760
# 3          6.22     55.052027    44.208463      34.678989
# 4          1.83     41.057403    43.008051      42.092428
# ..          ...           ...          ...            ...
# 563       27.51     38.394578    39.406814      42.421914
# 564        8.30     11.366906    20.800422      38.550451
# 565       20.94     43.283820    40.307123      42.421914
# 566       10.29     45.051640    30.103618      34.267131
# 567        9.17     56.597945    42.407844      41.598198
#
# [401 rows x 10 columns]

# %%
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, color='red')

plt.xlabel('Cloundiness')
plt.ylabel('Lat')

#y = mx + b
eq = f'y = {round(slope, 2)}x + {round(intercept, 2)}'
r_squared = f'r^2 = {round(rvalue ** 2, 2)}'
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")
plt.annotate(eq, (40, 20.5), color='red')
plt.annotate(r_squared, (40, 19), color='red')
plt.savefig("Northern - Cloundiness Lat")

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = south['Cloundiness']
y_values = south['Lat']

# y = mx + b
result = stats.linregress(x_values, y_values)
slope = result.slope
intercept = result.intercept
rvalue = result.rvalue

print(slope, intercept, rvalue)

# Get regression values
regress_values = x_values * slope + intercept
south['regress scloud'] = regress_values

south
# Out:
# 0.04067771872215152 -22.60469389801649 0.12014570974702915
# C:\Users\jocel\.conda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                        city    Lat    Long  MaxTemp  Humidity  Cloundiness  \
# 7                   Ushuaia -54.80  -68.30    46.40        61           75
# 11           Sena Madureira  -9.07  -68.66    95.05        44           87
# 12                   Atuona  -9.80 -139.03    78.30        67           21
# 13                  Mataura -46.19  168.86    48.99        86          100
# 14              Broken Hill -31.95  141.43    55.40        66           75
# ..                      ...    ...     ...      ...       ...          ...
# 541                   Luena -11.78   19.92    67.82        76          100
# 544               Tchibanga  -2.85   11.03    70.25        98          100
# 554  São Mateus do Maranhão  -4.04  -44.48    89.20        54           92
# 560               Maltahöhe -24.83   16.98    74.77        20           95
# 562                  Viedma -40.81  -63.00    60.01        49           95
#
#      Wind Speed  regress temp  regress hum  regress scloud
# 7         19.46           NaN   -20.591743      -19.553865
# 11         3.11           NaN   -20.861594      -19.065732
# 12        14.65           NaN   -20.496501      -21.750462
# 13         3.00           NaN   -20.194903      -18.536922
# 14         8.48           NaN   -20.512375      -19.553865
# ..          ...           ...          ...             ...
# 541        2.30           NaN   -20.353639      -18.536922
# 544        2.04           NaN   -20.004420      -18.536922
# 554        3.44           NaN   -20.702858      -18.862344
# 560       11.03           NaN   -21.242561      -18.740311
# 562        8.01           NaN   -20.782226      -18.740311
#
# [167 rows x 10 columns]

# %%
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, color='red')

plt.xlabel('Cloundiness')
plt.ylabel('Lat')

#y = mx + b
eq = f'y = {round(slope, 2)}x + {round(intercept, 2)}'
r_squared = f'r^2 = {round(rvalue ** 2, 2)}'
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")
plt.annotate(eq, (40, 20.5), color='red')
plt.annotate(r_squared, (40, 19), color='red')
plt.savefig("South - Cloundiness")

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Perform a linear regression on temperature vs. latitude
x_values = north['Wind Speed']
y_values = north['Lat']

# y = mx + b
result = stats.linregress(x_values, y_values)
slope = result.slope
intercept = result.intercept
rvalue = result.rvalue

print(slope, intercept, rvalue)

# Get regression values
regress_values = x_values * slope + intercept
north['regress wind'] = regress_values

south
# Out:
# 0.8038551728965159 32.06460074963109 0.19721301094426721
# C:\Users\jocel\.conda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
#                        city    Lat    Long  MaxTemp  Humidity  Cloundiness  \
# 7                   Ushuaia -54.80  -68.30    46.40        61           75
# 11           Sena Madureira  -9.07  -68.66    95.05        44           87
# 12                   Atuona  -9.80 -139.03    78.30        67           21
# 13                  Mataura -46.19  168.86    48.99        86          100
# 14              Broken Hill -31.95  141.43    55.40        66           75
# ..                      ...    ...     ...      ...       ...          ...
# 541                   Luena -11.78   19.92    67.82        76          100
# 544               Tchibanga  -2.85   11.03    70.25        98          100
# 554  São Mateus do Maranhão  -4.04  -44.48    89.20        54           92
# 560               Maltahöhe -24.83   16.98    74.77        20           95
# 562                  Viedma -40.81  -63.00    60.01        49           95
#
#      Wind Speed  regress temp  regress hum  regress scloud
# 7         19.46           NaN   -20.591743      -19.553865
# 11         3.11           NaN   -20.861594      -19.065732
# 12        14.65           NaN   -20.496501      -21.750462
# 13         3.00           NaN   -20.194903      -18.536922
# 14         8.48           NaN   -20.512375      -19.553865
# ..          ...           ...          ...             ...
# 541        2.30           NaN   -20.353639      -18.536922
# 544        2.04           NaN   -20.004420      -18.536922
# 554        3.44           NaN   -20.702858      -18.862344
# 560       11.03           NaN   -21.242561      -18.740311
# 562        8.01           NaN   -20.782226      -18.740311
#
# [167 rows x 10 columns]

# %%
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, color='red')

plt.xlabel('Wind Speed')
plt.ylabel('Lat')

#y = mx + b
eq = f'y = {round(slope, 2)}x + {round(intercept, 2)}'
r_squared = f'r^2 = {round(rvalue ** 2, 2)}'
plt.title("Northen Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")
plt.annotate(eq, (40, 20.5), color='red')
plt.annotate(r_squared, (40, 19), color='red')
plt.savefig("North - Wind")

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Perform a linear regression on temperature vs. latitude
x_values = south['Wind Speed']
y_values = south['Lat']

# y = mx + b
result = stats.linregress(x_values, y_values)
slope = result.slope
intercept = result.intercept
rvalue = result.rvalue

print(slope, intercept, rvalue)

# Get regression values
regress_values = x_values * slope + intercept
south['regress wind'] = regress_values

south
# Out:
# -0.37236837259015315 -17.27420218981474 -0.1655847109838989
# C:\Users\jocel\.conda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
#                        city    Lat    Long  MaxTemp  Humidity  Cloundiness  \
# 7                   Ushuaia -54.80  -68.30    46.40        61           75
# 11           Sena Madureira  -9.07  -68.66    95.05        44           87
# 12                   Atuona  -9.80 -139.03    78.30        67           21
# 13                  Mataura -46.19  168.86    48.99        86          100
# 14              Broken Hill -31.95  141.43    55.40        66           75
# ..                      ...    ...     ...      ...       ...          ...
# 541                   Luena -11.78   19.92    67.82        76          100
# 544               Tchibanga  -2.85   11.03    70.25        98          100
# 554  São Mateus do Maranhão  -4.04  -44.48    89.20        54           92
# 560               Maltahöhe -24.83   16.98    74.77        20           95
# 562                  Viedma -40.81  -63.00    60.01        49           95
#
#      Wind Speed  regress temp  regress hum  regress scloud  regress wind
# 7         19.46           NaN   -20.591743      -19.553865    -24.520491
# 11         3.11           NaN   -20.861594      -19.065732    -18.432268
# 12        14.65           NaN   -20.496501      -21.750462    -22.729399
# 13         3.00           NaN   -20.194903      -18.536922    -18.391307
# 14         8.48           NaN   -20.512375      -19.553865    -20.431886
# ..          ...           ...          ...             ...           ...
# 541        2.30           NaN   -20.353639      -18.536922    -18.130649
# 544        2.04           NaN   -20.004420      -18.536922    -18.033834
# 554        3.44           NaN   -20.702858      -18.862344    -18.555149
# 560       11.03           NaN   -21.242561      -18.740311    -21.381425
# 562        8.01           NaN   -20.782226      -18.740311    -20.256873
#
# [167 rows x 11 columns]

# %%
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, color='red')

plt.xlabel('Wind Speed')
plt.ylabel('Lat')

#y = mx + b
eq = f'y = {round(slope, 2)}x + {round(intercept, 2)}'
r_squared = f'r^2 = {round(rvalue ** 2, 2)}'
plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")
plt.annotate(eq, (40, 20.5), color='red')
plt.annotate(r_squared, (40, 19), color='red')
plt.savefig("South - Wind")
